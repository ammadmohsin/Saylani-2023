# %% [markdown]
# ## Scenario 1:
# #### Grocery Shopping List
# You are creating a program to manage a grocery shopping list. Users should be able to add items,
# remove items, and display the current list.

# %%
class GroceryList:
    def __init__(self):
        self.items = []

    def add_item(self, item):
        self.items.append(item)
        print(f"{item} added to the list.")

    def remove_item(self, item):
        if item in self.items:
            self.items.remove(item)
            print(f"{item} removed from the list.")
        else:
            print(f"{item} is not in the list.")

    def display_list(self):
        if self.items:
            print("Grocery List:")
            for item in self.items:
                print("-", item)
        else:
            print("Your grocery list is empty.")


def main():
    grocery_list = GroceryList()

    while True:
        print("\nOptions:")
        print("1. Add item")
        print("2. Remove item")
        print("3. Display list")
        print("4. Quit")

        choice = input("Enter your choice: ")

        if choice == "1":
            item = input("Enter the item to add: ")
            grocery_list.add_item(item)
        elif choice == "2":
            item = input("Enter the item to remove: ")
            grocery_list.remove_item(item)
        elif choice == "3":
            grocery_list.display_list()
        elif choice == "4":
            print("Thank you for using the grocery list program. Goodbye!")
            break
        else:
            print("Invalid choice. Please enter a number from 1 to 4.")


if __name__ == "__main__":
    main()
# Out:
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Apple added to the list.
#
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Orange added to the list.
#
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Banana added to the list.
#
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Orange removed from the list.
#
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Grocery List:
# - Apple
# - Banana
#
# Options:
# 1. Add item
# 2. Remove item
# 3. Display list
# 4. Quit
# Thank you for using the grocery list program. Goodbye!

# %% [markdown]
# ## Scenario 2:
# ### Student Grades
# You are managing student grades using a dictionary. You need to calculate the average grade.take
# atleast 5 Students grades & then calculate the average.

# %%
student_grades = {}

for i in range(5):
    student_name = input(f"Enter the name of student {i+1}: ")
    grade = float(input(f"Enter the grade for {student_name}: "))
    student_grades[student_name] = grade

total_grades = sum(student_grades.values())
number_of_students = len(student_grades)
average_grade = total_grades / number_of_students

print("Student Grades:")
for student, grade in student_grades.items():
    print(f"{student}: {grade}")

print(f"Average Grade: {average_grade}")
# Out:
# Student Grades:
# A: 65.0
# B: 90.0
# C: 70.0
# D: 85.0
# E: 60.0
# Average Grade: 74.0

# %% [markdown]
# -----
# ## Scenario 3:
# ### Word Frequency Counter
# You are given a list of words, and you need to count the frequency of each word.
# word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

# %%
word_list = ["apple", "banana", "apple", "orange", "banana", "grape", "apple"]

def count_word_frequency(word_list):
    word_counts = {}

    for word in word_list:
        if word not in word_counts:
            word_counts[word] = 1
        else:
            word_counts[word] += 1

    return word_counts

def display_word_frequency(word_counts):
    print("Word Frequency:")
    for word, count in word_counts.items():
        print(f"{word}: {count} times")

word_counts = count_word_frequency(word_list)

display_word_frequency(word_counts)
# Out:
# Word Frequency:
# apple: 3 times
# banana: 2 times
# orange: 1 times
# grape: 1 times

# %% [markdown]
# -----
# ## Scenario 4:
# ### Password Strength Checker
# You are creating a program to check the strength of passwords based on certain criteria.
# • Password should be at least 8 characters long.
# • Password should contain at least one digit.
# • Password should contain at least one letter.

# %%
def check_password_strength(password):
    if len(password) < 8:
        return "Weak: Password should be at least 8 characters long."

    if not any(char.isdigit() for char in password):
        return "Weak: Password should contain at least one digit."

    if not any(char.isalpha() for char in password):
        return "Weak: Password should contain at least one letter."
    return "Your Password is Strong ."

def main():
    password = input("Enter your password: ")
    result = check_password_strength(password)

    print(result)

if __name__ == "__main__":
    main()
# Out:
# Weak: Password should be at least 8 characters long.

# %% [markdown]
# -------
# ## Scenario 04:
# ### Voting System (Annual Employee Recognition Awards)

# %%
Candidate1 = input("Enter the name of Candidate 1: ")
Candidate2 = input("Enter the name of Candidate 2: ")
Candidate3 = input("Enter the name of Candidate 3: ")

C1_votes = 0
C2_votes = 0
C3_votes = 0

voter_id = [1,2,3,4,5,6,7,8,]

total_votes = len(voter_id)

while True:
    if voter_id ==[]:
        print("Voting Session Ended.")
        if C1_votes> C2_votes>C3_votes:
            percent = (C1_votes/total_votes)*100
            print(Candidate1,"has won the election with",percent,"%")
            break
        
        elif C2_votes> C1_votes>C3_votes:
            percent=(C2_votes/total_votes)*100
            print(Candidate2,"has won the election with", percent,"%")
            break
        elif C3_votes> C1_votes>C2_votes:
            percent=(C3_votes/total_votes)*100
            print(Candidate3,"has won the election with", percent,"%")
            break
        else:
            print("Both have equal votes")
            break

    voter = int(input("Enter your voter id: "))
    if voter in voter_id:
        print("You are a voter")
        voter_id.remove(voter)
        print("****--------<<<<<>-<>>>>>>--------****")
        print("Qaidi no 804 ",Candidate1, "Press 1")
        print("Patwari ",Candidate2, "Press 2")
        print("Jiyala ",Candidate3, "Press 3")
        print("****--------<<<<<>-<>>>>>>--------****")
        vote = int(input("Enter your Vote : "))
        if vote == 1 :
            C1_votes +=1
            print(Candidate1,"Thank you for your vote.")
        elif vote == 2 :
            C2_votes +=1
            print(Candidate2,"Thank you for your vote.")
        elif vote == 3 :
            C3_votes +=1
            print(Candidate3,"Thank you for your vote.")
        elif vote >3:
            print("Check your pressed key!!")

        else:
            print("You are not a voter OR You have already voted.")
# Out:
# You are a voter
# ****--------<<<<<>-<>>>>>>--------****
# Qaidi no 804  PTI Press 1
# Patwari  PML(N) Press 2
# Jiyala  PPP Press 3
# ****--------<<<<<>-<>>>>>>--------****
# PTI Thank you for your vote.
# You are a voter
# ****--------<<<<<>-<>>>>>>--------****
# Qaidi no 804  PTI Press 1
# Patwari  PML(N) Press 2
# Jiyala  PPP Press 3
# ****--------<<<<<>-<>>>>>>--------****
# PTI Thank you for your vote.
# You are a voter
# ****--------<<<<<>-<>>>>>>--------****
# Qaidi no 804  PTI Press 1
# Patwari  PML(N) Press 2
# Jiyala  PPP Press 3
# ****--------<<<<<>-<>>>>>>--------****
# PML(N) Thank you for your vote.
# You are a voter
# ****--------<<<<<>-<>>>>>>--------****
# Qaidi no 804  PTI Press 1
# Patwari  PML(N) Press 2
# Jiyala  PPP Press 3
# ****--------<<<<<>-<>>>>>>--------****
# PPP Thank you for your vote.
# You are a voter
# ****--------<<<<<>-<>>>>>>--------****
# Qaidi no 804  PTI Press 1
# Patwari  PML(N) Press 2
# Jiyala  PPP Press 3
# ...
